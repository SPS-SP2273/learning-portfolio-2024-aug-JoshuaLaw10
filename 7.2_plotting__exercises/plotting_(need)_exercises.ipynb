# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need) Exercises</span></div>

# %% [markdown]
# ## Exercise 1

# %%
from matplotlib import pyplot as plt

# Some data for plotting
x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25

plt.errorbar(x, y, 
             xerr=x_err, yerr=y_err,
             color='red', linestyle='dashed',
             marker='x', markerfacecolor='blue',
             ecolor='green',capsize=5,
             label='Y against X with errors')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %%
## Exercise 2

# %%
import numpy as np    # use numpy instead! use linspace

y = []

for x in range(51):
    inputy = (np.e ** (-x/10)) * np.sin(x)

    y += [inputy]
    
y = np.array(y)
y
# Out:
# array([ 0.00000000e+00,  7.61394433e-01,  7.44469767e-01,  1.04544273e-01,
#        -5.07299883e-01, -5.81616973e-01, -1.53346477e-01,  3.26249890e-01,
#         4.44547316e-01,  1.67554872e-01, -2.00134182e-01, -3.32867824e-01,
#        -1.61612657e-01,  1.14508876e-01,  2.44280766e-01,  1.45098830e-01,
#        -5.81266772e-02, -1.75631482e-01, -1.24137357e-01,  2.24169273e-02,
#         1.23553704e-01,  1.02453861e-01, -9.80753025e-04, -8.48410793e-02,
#        -8.21522155e-02, -1.08640932e-02,  5.66379447e-02,  6.42737346e-02,
#         1.64737980e-02, -3.65152732e-02, -4.91911980e-02, -1.82015737e-02,
#         2.24773669e-02,  3.68799165e-02,  1.76572193e-02, -1.29299962e-02,
#        -2.70990901e-02, -1.59105321e-02,  6.62999386e-03,  1.95090609e-02,
#         1.36472236e-02, -2.62880200e-03, -1.37437693e-02, -1.12859847e-02,
#         2.17332551e-04,  9.45268431e-03,  9.06462835e-03,  1.12393179e-03,
#        -6.32254153e-03, -7.10219836e-03, -1.76786786e-03])

# %%
x = np.linspace(0, 50, 100)
y = (np.e ** (-x/10)) * np.sin(x)
# Out:
# array([ 0.00000000e+00,  4.60021525e-01,  7.65520103e-01,  8.58074697e-01,
#         7.35946984e-01,  4.49052402e-01,  8.20263581e-02, -2.69409443e-01,
#        -5.22468835e-01, -6.25912805e-01, -5.69307096e-01, -3.81604269e-01,
#        -1.20415950e-01,  1.44557487e-01,  3.49404431e-01,  4.50773642e-01,
#         4.34295720e-01,  3.15244818e-01,  1.32027444e-01, -6.52509489e-02,
#        -2.27926623e-01, -3.20309951e-01, -3.26998272e-01, -2.54620784e-01,
#        -1.28131943e-01,  1.69339243e-02,  1.44001206e-01,  2.24324891e-01,
#         2.43132083e-01,  2.01822561e-01,  1.16079270e-01,  1.07348430e-02,
#        -8.70630141e-02, -1.54584718e-01, -1.78545514e-01, -1.57384102e-01,
#        -1.00510739e-01, -2.49962945e-02,  4.92578189e-02,  1.04564501e-01,
#         1.29480076e-01,  1.20948960e-01,  8.42305773e-02,  3.08391339e-02,
#        -2.48187444e-02, -6.91770103e-02, -9.26829485e-02, -9.17025958e-02,
#        -6.88236152e-02, -3.16369531e-02,  9.56437521e-03,  4.45134392e-02,
#         6.54291808e-02,  6.86436940e-02,  5.50867148e-02,  2.96209208e-02,
#        -5.02134298e-04, -2.76106582e-02, -4.54929021e-02, -5.07466348e-02,
#        -4.33251641e-02, -2.62261479e-02, -4.48018341e-03,  1.62509854e-02,
#         3.10929491e-02,  3.70520064e-02,  3.35524459e-02,  2.23423058e-02,
#         6.85088989e-03, -8.79520390e-03, -2.08287491e-02, -2.67108487e-02,
#        -2.56218195e-02, -1.84925997e-02, -7.61329109e-03,  4.04665356e-03,
#         1.36158569e-02,  1.90002298e-02,  1.93105130e-02,  1.49597909e-02,
#         7.43929787e-03, -1.14280469e-03, -8.62629618e-03, -1.33219788e-02,
#        -1.43715400e-02, -1.18735710e-02, -6.76798668e-03, -5.29776783e-04,
#         5.23614536e-03,  9.19232787e-03,  1.05638416e-02,  9.27008448e-03,
#         5.87740411e-03,  1.40111532e-03, -2.98113528e-03, -6.22739773e-03,
#        -7.66826989e-03, -7.13164568e-03, -4.93621252e-03, -1.76786786e-03])

# %%
x = np.linspace(0, 50, 100)
y = (np.e ** (-x/10)) * np.sin(x)

plt.plot(x, y)
plt.xlabel('x',fontsize = 15,color = 'darkorange')
plt.ylabel('y',fontsize = 15,color = 'darkorange',rotation = 0)
plt.title('$e^{-x/10}\\sin(x)$',fontsize = 20)
plt.grid(visible = True, axis ='both',alpha =0.25)
plt.ylim(top=1, bottom = -1)

plt.show()
